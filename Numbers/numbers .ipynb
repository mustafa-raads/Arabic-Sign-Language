# %% [markdown]
# # Training

# %% [markdown]
# ## Mount Google Drive and Install YOLOv8

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Access YOLOv8 root folder
import os
os.chdir("gdrive/MyDrive/numbers")

# %%
# Install YOLOv8
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.175 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 26.3/166.8 GB disk)

# %% [markdown]
# ## Dataset

# %%
# Check Dataset
# !ls data/
# Out:
# numbers.yaml  nums.zip

# %%
# Unzip Dataset
# !unzip data/nums.zip -d ./data

# %%
# Check data folder
# %cd data/

# !ls
# Out:
# /content/gdrive/MyDrive/numbers/data
# numbers.yaml  nums  nums.zip

# %% [markdown]
# ## Data File

# %%
# Download sample data file
# !gdown https://drive.google.com/uc?id=1joW_me3Gtzxm4d48edbMsOpooV8snDdn
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1joW_me3Gtzxm4d48edbMsOpooV8snDdn
# To: /content/gdrive/MyDrive/numbers4/data/data.yaml
# 100% 166/166 [00:00<00:00, 1.07MB/s]

# %%
# Rename sample data file
import os
os.rename("data.yaml", "numbers.yaml")

# !ls
# Out:
# numbers  numbers.yaml  numbers.zip

# %%
# Get Absolute Path
import os

print(os.getcwd())
# Out:
# /content/gdrive/MyDrive/numbers

# %%
# Back to root folder
# %cd ../
# Out:
# /content/gdrive/MyDrive/numbers

# %% [markdown]
# ## Training Process

# %%
# Train
# !yolo detect train model=yolov8n.pt data=data/numbers.yaml imgsz=640 workers=8 batch=16 device=0 epochs=200 patience=100 name=ar_num_m

# %%
# See the accuracy
# %load_ext tensorboard

# %tensorboard --logdir runs/detect/ar_sing

# %% [markdown]
# ## Continue Training

# %%
# Continue Train
# !yolo detect train model=runs/detect/ar_num_m/weights/last.pt data=data/number.yaml resume=True
# Out:
# Ultralytics YOLOv8.0.175 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# See the accuracy
# %load_ext tensorboard

# %tensorboard --logdir runs/detect/ar_sing5/
